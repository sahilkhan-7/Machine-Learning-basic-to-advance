# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wine_data.csv',header=None,usecols=[0,1,2])
df.columns=['Class label', 'Alcohol', 'Malic acid']

# %%
df
# Out:
#      Class label  Alcohol  Malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['Malic acid'])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
color_dict={1:'red',3:'green',2:'blue'}
sns.scatterplot(x = 'Alcohol',y = 'Malic acid',hue='Class label', data = df,palette=color_dict)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class label', axis=1),
                                                    df['Class label'],
                                                    test_size=0.3,
                                                    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %% [markdown]
# # MinMaxScaler from scratch

# %%
class min_max_scaler:
    def __init__(self) -> None:
        self.mins = list()
        self.maxs = list()
        self.cols = list()
        
    def fit(self, train_df):
        self.mins = train_df.min().values
        self.maxs = train_df.max().values
        self.cols = train_df.columns
        
    def transform(self, test_df):
        if len(test_df.columns) != len(self.cols):
            raise ValueError("Number of columns in the test data must match the number of columns in the training data.")
        
        test_df = test_df.copy()
        for i, col in enumerate(test_df.columns):
            test_df[col] = (test_df[col] - self.mins[i])/(self.maxs[i] - self.mins[i])
        return test_df
    
    def fit_transform(self, train_df):
        self.fit(train_df)
        return self.transform(train_df)

# %%
# Scikit Learn's MinMaxScaler 
scikit_scaler = MinMaxScaler()

scikit_scaler.fit(df.drop('Class label', axis=1))

scikit_scaled_df = scikit_scaler.transform(df.drop('Class label', axis = 1))

scikit_scaled_df = pd.DataFrame(scikit_scaled_df, columns = df.drop('Class label', axis = 1).columns)
scikit_scaled_df
# Out:
#       Alcohol  Malic acid
# 0    0.842105    0.191700
# 1    0.571053    0.205534
# 2    0.560526    0.320158
# 3    0.878947    0.239130
# 4    0.581579    0.365613
# ..        ...         ...
# 173  0.705263    0.970356
# 174  0.623684    0.626482
# 175  0.589474    0.699605
# 176  0.563158    0.365613
# 177  0.815789    0.664032
#
# [178 rows x 2 columns]

# %%
my_scaler = min_max_scaler()

my_scaled_df = my_scaler.fit_transform(df.drop('Class label', axis = 1))
my_scaled_df
# Out:
#       Alcohol  Malic acid
# 0    0.842105    0.191700
# 1    0.571053    0.205534
# 2    0.560526    0.320158
# 3    0.878947    0.239130
# 4    0.581579    0.365613
# ..        ...         ...
# 173  0.705263    0.970356
# 174  0.623684    0.626482
# 175  0.589474    0.699605
# 176  0.563158    0.365613
# 177  0.815789    0.664032
#
# [178 rows x 2 columns]

# %%
np.round(X_train.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.4         1.6
# 50%       13.0         1.9
# 75%       13.6         3.2
# max       14.8         5.6

# %%
np.round(X_train_scaled.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.4         0.2
# 50%        0.5         0.2
# 75%        0.7         0.5
# max        1.0         1.0

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Alcohol'], X_train['Malic acid'],c=y_train)
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Alcohol'], X_train_scaled['Malic acid'],c=y_train)
ax2.set_title("After Scaling")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Alcohol'], ax=ax1)
sns.kdeplot(X_train['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Alcohol Distribution Before Scaling')
sns.kdeplot(X_train['Alcohol'], ax=ax1)

# after scaling
ax2.set_title('Alcohol Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Malic acid Distribution Before Scaling')
sns.kdeplot(X_train['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('Malic acid Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()
