# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
data = {"A": np.random.randint(0, 100, 10)}
df = pd.DataFrame(data)
df
# Out:
#     A
# 0  44
# 1  47
# 2  64
# 3  67
# 4  67
# 5   9
# 6  83
# 7  21
# 8  36
# 9  87

# %%
from scipy.stats import zscore

df["A_zscore"] = zscore(df["A"])
df
# Out:
#     A  A_zscore
# 0  44 -0.348980
# 1  47 -0.225810
# 2  64  0.472149
# 3  67  0.595318
# 4  67  0.595318
# 5   9 -1.785954
# 6  83  1.252221
# 7  21 -1.293277
# 8  36 -0.677431
# 9  87  1.416447

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler, RobustScaler

# %%
sc = StandardScaler()
df['Standard'] = sc.fit_transform(df[['A']])
df
# Out:
#     A  A_zscore  Standard
# 0  44 -0.348980 -0.348980
# 1  47 -0.225810 -0.225810
# 2  64  0.472149  0.472149
# 3  67  0.595318  0.595318
# 4  67  0.595318  0.595318
# 5   9 -1.785954 -1.785954
# 6  83  1.252221  1.252221
# 7  21 -1.293277 -1.293277
# 8  36 -0.677431 -0.677431
# 9  87  1.416447  1.416447

# %%
mms = MinMaxScaler()
df['Minmax'] = mms.fit_transform(df[['A']])
df
# Out:
#     A  A_zscore  Standard    Minmax
# 0  44 -0.348980 -0.348980  0.448718
# 1  47 -0.225810 -0.225810  0.487179
# 2  64  0.472149  0.472149  0.705128
# 3  67  0.595318  0.595318  0.743590
# 4  67  0.595318  0.595318  0.743590
# 5   9 -1.785954 -1.785954  0.000000
# 6  83  1.252221  1.252221  0.948718
# 7  21 -1.293277 -1.293277  0.153846
# 8  36 -0.677431 -0.677431  0.346154
# 9  87  1.416447  1.416447  1.000000

# %%
mas = MaxAbsScaler()
df['MaxAbs'] = mas.fit_transform(df[['A']])
df
# Out:
#     A  A_zscore  Standard    Minmax    MaxAbs
# 0  44 -0.348980 -0.348980  0.448718  0.505747
# 1  47 -0.225810 -0.225810  0.487179  0.540230
# 2  64  0.472149  0.472149  0.705128  0.735632
# 3  67  0.595318  0.595318  0.743590  0.770115
# 4  67  0.595318  0.595318  0.743590  0.770115
# 5   9 -1.785954 -1.785954  0.000000  0.103448
# 6  83  1.252221  1.252221  0.948718  0.954023
# 7  21 -1.293277 -1.293277  0.153846  0.241379
# 8  36 -0.677431 -0.677431  0.346154  0.413793
# 9  87  1.416447  1.416447  1.000000  1.000000

# %%
rb = RobustScaler()
df['Robust'] = rb.fit_transform(df[['A']])
df
# Out:
#     A  A_zscore  Standard    Minmax    MaxAbs    Robust
# 0  44 -0.348980 -0.348980  0.448718  0.505747 -0.396552
# 1  47 -0.225810 -0.225810  0.487179  0.540230 -0.293103
# 2  64  0.472149  0.472149  0.705128  0.735632  0.293103
# 3  67  0.595318  0.595318  0.743590  0.770115  0.396552
# 4  67  0.595318  0.595318  0.743590  0.770115  0.396552
# 5   9 -1.785954 -1.785954  0.000000  0.103448 -1.603448
# 6  83  1.252221  1.252221  0.948718  0.954023  0.948276
# 7  21 -1.293277 -1.293277  0.153846  0.241379 -1.189655
# 8  36 -0.677431 -0.677431  0.346154  0.413793 -0.672414
# 9  87  1.416447  1.416447  1.000000  1.000000  1.086207

# %%
a_mean = df['A'].mean()
a_max = df['A'].max()
a_min = df['A'].min()

df['Mean_Norm'] = df['A'].apply(lambda x: (x - a_mean)/(a_max - a_min))
df
# Out:
#     A  A_zscore  Standard    Minmax    MaxAbs    Robust  Mean_Norm
# 0  44 -0.348980 -0.348980  0.448718  0.505747 -0.396552  -0.108974
# 1  47 -0.225810 -0.225810  0.487179  0.540230 -0.293103  -0.070513
# 2  64  0.472149  0.472149  0.705128  0.735632  0.293103   0.147436
# 3  67  0.595318  0.595318  0.743590  0.770115  0.396552   0.185897
# 4  67  0.595318  0.595318  0.743590  0.770115  0.396552   0.185897
# 5   9 -1.785954 -1.785954  0.000000  0.103448 -1.603448  -0.557692
# 6  83  1.252221  1.252221  0.948718  0.954023  0.948276   0.391026
# 7  21 -1.293277 -1.293277  0.153846  0.241379 -1.189655  -0.403846
# 8  36 -0.677431 -0.677431  0.346154  0.413793 -0.672414  -0.211538
# 9  87  1.416447  1.416447  1.000000  1.000000  1.086207   0.442308

# %%
# Measure of Central Tendency

# %%
class standard_scaler:
    def __init__(self) -> None:
        self.mean_ = list()
        self.std_ = list()
        self.cols = list()
        
        
    def fit(self, train_df):
        self.mean_ = train_df.mean().values
        self.std_ = train_df.std(ddof=0).values
        self.cols = train_df.columns
        # print("Fitted means:", self.mean_)
        # print("Fitted stds:", self.std_)
    
    def transform(self, test_df):
        
        if len(self.cols) != len(test_df.columns):
            raise ValueError("Number of columns in test data must match the number of columns in training data.")
        
        test_df = test_df.copy()
        for i, col in enumerate(test_df.columns):
            test_df[col] = (test_df[col] - self.mean_[i])/self.std_[i]
            
        return test_df

# %%
scaler = standard_scaler()

scaler.fit(df[['A']])
df['Scaler'] = scaler.transform(df[['A']])

# %%
sc.mean_, sc.scale_
# Out:
# (array([52.5]), array([24.35672392]))

# %%
scaler.mean_, scaler.std_
# Out:
# (array([52.5]), array([24.35672392]))
